# %%
nm = "suresh kumar"

# %%
nm[0]
# Out:
# 's'

# %%
for i in nm :
  print (i)
# Out:
# s
# u
# r
# e
# s
# h
#
# k
# u
# m
# a
# r

# %%
i=0
while i< len(nm): 
  print(nm[i])
  i+=1
# Out:
# s
# u
# r
# e
# s
# h
#
# k
# u
# m
# a
# r

# %%
print(nm)
# Out:
# suresh kumar

# %% [markdown]
# # Slicing

# %%
print(id(nm))
# Out:
# 140409313205296

# %%
print (nm[0:4])
# Out:
# sure

# %%
print (nm[0:90])
# Out:
# suresh kumar

# %%
print(nm[::])
# Out:
# suresh kumar

# %%
print(nm[::1])
# Out:
# suresh kumar

# %%
print(nm[::2])
# Out:
# srs ua

# %%
print(nm[2::])
# Out:
# resh kumar

# %%
print (nm[::-1])
# Out:
# ramuk hserus

# %%
print (nm[::-2])
# Out:
# rmkheu

# %%
print(nm)
# Out:
# suresh kumar

# %%
print (nm[-1])
# Out:
# r

# %%
print (nm[-6:-1])
# Out:
#  kuma

# %%
print (nm[-6:])
# Out:
#  kumar

# %%
print(nm[:5:-1])
# Out:
# ramuk

# %%
s="1"

# %%
s+2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-bc338e43f4d9> in <module>()
# ----> 1 s+2
#
# TypeError: must be str, not int

# %%
int(s)+2
# Out:
# 3

# %%
print (nm)
# Out:
# suresh kumar

# %%
print (nm.upper())
# Out:
# SURESH KUMAR

# %%
print (nm.capitalize())
# Out:
# Suresh kumar

# %%
len(nm)
# Out:
# 12

# %%
print (nm.count("r"))
# Out:
# 2
