# %%
a=1

# %%
print(a)
# Out:
# 1

# %%
b=20

# %%
print(b)
# Out:
# 20

# %%
a+b
# Out:
# 21

# %%
c=10.5

# %%
print(c)
# Out:
# 10.5

# %%
a+c
# Out:
# 11.5

# %%
type(c)
# Out:
# float

# %%
del b

# %%
print(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-4851c8fca996> in <module>()
# ----> 1 print(b)
#
# NameError: name 'b' is not defined

# %%
aa= input("enter number")
# Out:
# enter number57

# %%
print(aa)
# Out:
# 57

# %%
aa+a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-743aef77057c> in <module>()
# ----> 1 aa+a
#
# TypeError: must be str, not int

# %%
print(type(a) , " " , type(aa))
# Out:
# <class 'int'>   <class 'str'>

# %%
int(aa) +a
# Out:
# 58

# %%
aa+str(a)
# Out:
# '571'

# %%
a=10
b=20

if (a>b):
    print("a")
    print(a)
else :
    print("b")
    print(b)
# Out:
# b
# 20

# %%
a=int(input ("enter first number"))
b=int(input("enter second number"))

if (a>b):
    print("a")
    print(a)
else :
    print("b")
    print(b)
# Out:
# enter first number2
# enter second number22
# b
# 22

# %%
a=int(input ("enter age"))
if(a==18):
    print("age is 18")
elif(a==21):
    print("age is 21")
else :
    print("not 18,21")
# Out:
# enter age3434
# not 18,21

# %%
print('enter ')
print("ok")
# Out:
# enter
# ok
