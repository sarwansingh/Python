# %%
#Thanksgiving data
import numpy as np
import pandas as pd
data = pd.read_csv("thanks.csv", encoding="Latin-1")
data.head()
# Out:
#    RespondentID Do you celebrate Thanksgiving?  \
# 0    4337954960                            Yes
# 1    4337951949                            Yes
# 2    4337935621                            Yes
# 3    4337933040                            Yes
# 4    4337931983                            Yes
#
#   What is typically the main dish at your Thanksgiving dinner?  \
# 0                                             Turkey
# 1                                             Turkey
# 2                                             Turkey
# 3                                             Turkey
# 4                                           Tofurkey
#
#   What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How is the main dish typically cooked?  \
# 0                                  Baked
# 1                                  Baked
# 2                                Roasted
# 3                                  Baked
# 4                                  Baked
#
#   How is the main dish typically cooked? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What kind of stuffing/dressing do you typically have?  \
# 0                                        Bread-based
# 1                                        Bread-based
# 2                                         Rice-based
# 3                                        Bread-based
# 4                                        Bread-based
#
#   What kind of stuffing/dressing do you typically have? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What type of cranberry saucedo you typically have?  \
# 0                                               None
# 1                             Other (please specify)
# 2                                           Homemade
# 3                                           Homemade
# 4                                             Canned
#
#   What type of cranberry saucedo you typically have? - Other (please specify)  \
# 0                                                NaN
# 1                    Homemade cranberry gelatin ring
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#           ...          \
# 0         ...
# 1         ...
# 2         ...
# 3         ...
# 4         ...
#
#   Have you ever tried to meet up with hometown friends on Thanksgiving night?  \
# 0                                                Yes
# 1                                                 No
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Have you ever attended a "Friendsgiving?"  \
# 0                                        No
# 1                                        No
# 2                                       Yes
# 3                                        No
# 4                                        No
#
#   Will you shop any Black Friday sales on Thanksgiving Day?  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                 No
#
#   Do you work in retail? Will you employer make you work on Black Friday?  \
# 0                     No                                              NaN
# 1                     No                                              NaN
# 2                     No                                              NaN
# 3                     No                                              NaN
# 4                     No                                              NaN
#
#   How would you describe where you live?      Age What is your gender?  \
# 0                               Suburban  18 - 29                 Male
# 1                                  Rural  18 - 29               Female
# 2                               Suburban  18 - 29                 Male
# 3                                  Urban  30 - 44                 Male
# 4                                  Urban  30 - 44                 Male
#
#   How much total combined money did all members of your HOUSEHOLD earn last year?  \
# 0                                 $75,000 to $99,999
# 1                                 $50,000 to $74,999
# 2                                       $0 to $9,999
# 3                                    $200,000 and up
# 4                               $100,000 to $124,999
#
#             US Region
# 0     Middle Atlantic
# 1  East South Central
# 2            Mountain
# 3             Pacific
# 4             Pacific
#
# [5 rows x 65 columns]

# %%
data.columns[:]
data.columns[3:4]
# Out:
# Index(['What is typically the main dish at your Thanksgiving dinner? - Other (please specify)'], dtype='object')

# %%
data.tail(5)
# Out:
#       RespondentID Do you celebrate Thanksgiving?  \
# 1053    4335944082                            Yes
# 1054    4335943173                            Yes
# 1055    4335943060                            Yes
# 1056    4335934708                            Yes
# 1057    4335894916                            Yes
#
#      What is typically the main dish at your Thanksgiving dinner?  \
# 1053                                             Turkey
# 1054                                             Turkey
# 1055                             Other (please specify)
# 1056                                             Turkey
# 1057                                             Turkey
#
#      What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 1053                                                NaN
# 1054                                                NaN
# 1055                                               Duck
# 1056                                                NaN
# 1057                                                NaN
#
#      How is the main dish typically cooked?  \
# 1053                                Roasted
# 1054                                  Baked
# 1055                                  Baked
# 1056                                  Baked
# 1057                                  Baked
#
#      How is the main dish typically cooked? - Other (please specify)  \
# 1053                                                NaN
# 1054                                                NaN
# 1055                                                NaN
# 1056                                                NaN
# 1057                                                NaN
#
#      What kind of stuffing/dressing do you typically have?  \
# 1053                                        Bread-based
# 1054                                        Bread-based
# 1055                                         Rice-based
# 1056                                               None
# 1057                                        Bread-based
#
#      What kind of stuffing/dressing do you typically have? - Other (please specify)  \
# 1053                                                NaN
# 1054                                                NaN
# 1055                                                NaN
# 1056                                                NaN
# 1057                                                NaN
#
#      What type of cranberry saucedo you typically have?  \
# 1053                                           Homemade
# 1054                                             Canned
# 1055                                               None
# 1056                                           Homemade
# 1057                                             Canned
#
#      What type of cranberry saucedo you typically have? - Other (please specify)  \
# 1053                                                NaN
# 1054                                                NaN
# 1055                                                NaN
# 1056                                                NaN
# 1057                                                NaN
#
#         ...     \
# 1053    ...
# 1054    ...
# 1055    ...
# 1056    ...
# 1057    ...
#
#      Have you ever tried to meet up with hometown friends on Thanksgiving night?  \
# 1053                                                Yes
# 1054                                                 No
# 1055                                                Yes
# 1056                                                Yes
# 1057                                                Yes
#
#      Have you ever attended a "Friendsgiving?"  \
# 1053                                       Yes
# 1054                                        No
# 1055                                       Yes
# 1056                                        No
# 1057                                       Yes
#
#      Will you shop any Black Friday sales on Thanksgiving Day?  \
# 1053                                                 No
# 1054                                                 No
# 1055                                                Yes
# 1056                                                Yes
# 1057                                                Yes
#
#      Do you work in retail? Will you employer make you work on Black Friday?  \
# 1053                     No                                              NaN
# 1054                     No                                              NaN
# 1055                     No                                              NaN
# 1056                    Yes                                              Yes
# 1057                     No                                              NaN
#
#      How would you describe where you live?      Age What is your gender?  \
# 1053                                  Rural  30 - 44               Female
# 1054                               Suburban      60+               Female
# 1055                                  Urban      60+                 Male
# 1056                                    NaN      NaN                  NaN
# 1057                                    NaN      NaN                  NaN
#
#      How much total combined money did all members of your HOUSEHOLD earn last year?  \
# 1053                               $100,000 to $124,999
# 1054                                 $50,000 to $74,999
# 1055                               $100,000 to $124,999
# 1056                                                NaN
# 1057                                                NaN
#
#      US Region
# 1053  Mountain
# 1054   Pacific
# 1055   Pacific
# 1056       NaN
# 1057       NaN
#
# [5 rows x 65 columns]

# %%
#Unique Method
#a=data["Do you celebrate Thanksgiving?"]
print(a)
a=data["Do you celebrate Thanksgiving?"].unique()
b=np.array(data["Do you celebrate Thanksgiving?"].unique())
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-eb59d44b9d60> in <module>()
#       1 #Unique Method
#       2 #a=data["Do you celebrate Thanksgiving?"]
# ----> 3 print(a)
#       4 a=data["Do you celebrate Thanksgiving?"].unique()
#       5 b=np.array(data["Do you celebrate Thanksgiving?"].unique())
#
# NameError: name 'a' is not defined

# %%
a=data.columns[50:]
a

# %%
#Series Function
data["What is your gender?"].value_counts(dropna=False)

# %%
#To get the gender column's data in 0 and 1 form
import math

def gender_code(gender_string):
    if isinstance(gender_string, float) and math.isnan(gender_string):
        return gender_string
    return int(gender_string == "Female")

data["gender"] = data["What is your gender?"].apply(gender_code)
data["gender"].value_counts(dropna=False)

# %%
#Apply method on pandas datafram which works across each column in the dataframe
data.apply(lambda x: x.dtype).head()
# Out:
# RespondentID                                                                             object
# Do you celebrate Thanksgiving?                                                           object
# What is typically the main dish at your Thanksgiving dinner?                             object
# What is typically the main dish at your Thanksgiving dinner? - Other (please specify)    object
# How is the main dish typically cooked?                                                   object
# dtype: object

# %%
#Series Function
data["How much total combined money did all members of your HOUSEHOLD earn last year?"].value_counts(dropna=False)
# Out:
# $25,000 to $49,999      180
# Prefer not to answer    136
# $50,000 to $74,999      135
# $75,000 to $99,999      133
# $100,000 to $124,999    111
# $200,000 and up          80
# $10,000 to $24,999       68
# $0 to $9,999             66
# $125,000 to $149,999     49
# $150,000 to $174,999     40
# NaN                      33
# $175,000 to $199,999     27
# Name: How much total combined money did all members of your HOUSEHOLD earn last year?, dtype: int64

# %%
#Cleaning the Income Column to get values in Numericalform
#checks for float and math.isnan checks whether the argument is a number and equates to NAN
#checks if the float x is a nan
#pandas cannot store NaN values in integer columns so any value comes nan, the whole col is chanaged to float
import numpy as np

def clean_income(value):
    if value == "$200,000 and up":
        return 200000
    elif value == "Prefer not to answer":
        return np.nan
    elif isinstance(value, float) and math.isnan(value):
        return np.nan
    value = value.replace(",", "").replace("$", "")
    income_high, income_low = value.split(" to ")
    return (int(income_high) + int(income_low)) / 2

data["income"] = data["How much total combined money did all members of your HOUSEHOLD earn last year?"].apply(clean_income)
#data["income"]
data["income"]

data.head(5)
# Out:
#    RespondentID Do you celebrate Thanksgiving?  \
# 0    4337954960                            Yes
# 1    4337951949                            Yes
# 2    4337935621                            Yes
# 3    4337933040                            Yes
# 4    4337931983                            Yes
#
#   What is typically the main dish at your Thanksgiving dinner?  \
# 0                                             Turkey
# 1                                             Turkey
# 2                                             Turkey
# 3                                             Turkey
# 4                                           Tofurkey
#
#   What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How is the main dish typically cooked?  \
# 0                                  Baked
# 1                                  Baked
# 2                                Roasted
# 3                                  Baked
# 4                                  Baked
#
#   How is the main dish typically cooked? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What kind of stuffing/dressing do you typically have?  \
# 0                                        Bread-based
# 1                                        Bread-based
# 2                                         Rice-based
# 3                                        Bread-based
# 4                                        Bread-based
#
#   What kind of stuffing/dressing do you typically have? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What type of cranberry saucedo you typically have?  \
# 0                                               None
# 1                             Other (please specify)
# 2                                           Homemade
# 3                                           Homemade
# 4                                             Canned
#
#   What type of cranberry saucedo you typically have? - Other (please specify)  \
# 0                                                NaN
# 1                    Homemade cranberry gelatin ring
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#      ...    Have you ever attended a "Friendsgiving?"  \
# 0    ...                                           No
# 1    ...                                           No
# 2    ...                                          Yes
# 3    ...                                           No
# 4    ...                                           No
#
#   Will you shop any Black Friday sales on Thanksgiving Day?  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                 No
#
#   Do you work in retail? Will you employer make you work on Black Friday?  \
# 0                     No                                              NaN
# 1                     No                                              NaN
# 2                     No                                              NaN
# 3                     No                                              NaN
# 4                     No                                              NaN
#
#   How would you describe where you live?      Age What is your gender?  \
# 0                               Suburban  18 - 29                 Male
# 1                                  Rural  18 - 29               Female
# 2                               Suburban  18 - 29                 Male
# 3                                  Urban  30 - 44                 Male
# 4                                  Urban  30 - 44                 Male
#
#   How much total combined money did all members of your HOUSEHOLD earn last year?  \
# 0                                 $75,000 to $99,999
# 1                                 $50,000 to $74,999
# 2                                       $0 to $9,999
# 3                                    $200,000 and up
# 4                               $100,000 to $124,999
#
#             US Region    income
# 0     Middle Atlantic   87499.5
# 1  East South Central   62499.5
# 2            Mountain    4999.5
# 3             Pacific  200000.0
# 4             Pacific  112499.5
#
# [5 rows x 66 columns]

# %%
print(data["income"])
#Series Function

data["What type of cranberry saucedo you typically have?"].value_counts()
#data["What type of cranberry saucedo you typically have?"]
# Out:
# 0        87499.5
# 1        62499.5
# 2         4999.5
# 3       200000.0
# 4       112499.5
# 5         4999.5
# 6        37499.5
# 7            NaN
# 8        87499.5
# 9        37499.5
# 10       37499.5
# 11       37499.5
# 12        4999.5
# 13        4999.5
# 14       62499.5
# 15      200000.0
# 16      200000.0
# 17       87499.5
# 18       37499.5
# 19       87499.5
# 20       87499.5
# 21        4999.5
# 22        4999.5
# 23        4999.5
# 24       62499.5
# 25      200000.0
# 26       62499.5
# 27      112499.5
# 28           NaN
# 29       87499.5
#           ...
# 1028         NaN
# 1029     62499.5
# 1030     17499.5
# 1031     87499.5
# 1032         NaN
# 1033     87499.5
# 1034         NaN
# 1035     37499.5
# 1036     62499.5
# 1037     17499.5
# 1038    112499.5
# 1039     87499.5
# 1040     62499.5
# 1041     37499.5
# 1042    137499.5
# 1043     87499.5
# 1044     37499.5
# 1045     87499.5
# 1046     17499.5
# 1047     37499.5
# 1048     87499.5
# 1049         NaN
# 1050    137499.5
# 1051    137499.5
# 1052      4999.5
# 1053    112499.5
# 1054     62499.5
# 1055    112499.5
# 1056         NaN
# 1057         NaN
# Name: income, Length: 1058, dtype: float64
# Canned                    502
# Homemade                  301
# None                      146
# Other (please specify)     25
# Name: What type of cranberry saucedo you typically have?, dtype: int64

# %%
#Grouping Data
homemade = data[data["What type of cranberry saucedo you typically have?"] == "Homemade"]
canned = data[data["What type of cranberry saucedo you typically have?"] == "Canned"]
print(homemade["income"].mean())
print(canned["income"].mean())
print(homemade["What type of cranberry saucedo you typically have?"])
print(canned["What type of cranberry saucedo you typically have?"])
# Out:
# 94878.1072874494
# 83823.40340909091
# 2       Homemade
# 3       Homemade
# 5       Homemade
# 7       Homemade
# 13      Homemade
# 14      Homemade
# 16      Homemade
# 20      Homemade
# 21      Homemade
# 23      Homemade
# 25      Homemade
# 28      Homemade
# 30      Homemade
# 32      Homemade
# 33      Homemade
# 37      Homemade
# 39      Homemade
# 42      Homemade
# 44      Homemade
# 46      Homemade
# 52      Homemade
# 54      Homemade
# 56      Homemade
# 57      Homemade
# 62      Homemade
# 64      Homemade
# 66      Homemade
# 70      Homemade
# 82      Homemade
# 83      Homemade
#           ...
# 921     Homemade
# 929     Homemade
# 931     Homemade
# 933     Homemade
# 940     Homemade
# 943     Homemade
# 944     Homemade
# 950     Homemade
# 953     Homemade
# 959     Homemade
# 960     Homemade
# 975     Homemade
# 983     Homemade
# 984     Homemade
# 993     Homemade
# 996     Homemade
# 1008    Homemade
# 1011    Homemade
# 1012    Homemade
# 1014    Homemade
# 1016    Homemade
# 1017    Homemade
# 1025    Homemade
# 1027    Homemade
# 1030    Homemade
# 1034    Homemade
# 1048    Homemade
# 1049    Homemade
# 1053    Homemade
# 1056    Homemade
# Name: What type of cranberry saucedo you typically have?, Length: 301, dtype: object
# 4       Canned
# 6       Canned
# 8       Canned
# 11      Canned
# 12      Canned
# 15      Canned
# 18      Canned
# 19      Canned
# 26      Canned
# 27      Canned
# 38      Canned
# 43      Canned
# 48      Canned
# 53      Canned
# 58      Canned
# 59      Canned
# 60      Canned
# 68      Canned
# 69      Canned
# 71      Canned
# 74      Canned
# 76      Canned
# 79      Canned
# 80      Canned
# 86      Canned
# 87      Canned
# 89      Canned
# 90      Canned
# 91      Canned
# 97      Canned
#          ...
# 995     Canned
# 998     Canned
# 999     Canned
# 1002    Canned
# 1003    Canned
# 1004    Canned
# 1005    Canned
# 1010    Canned
# 1013    Canned
# 1019    Canned
# 1021    Canned
# 1022    Canned
# 1023    Canned
# 1024    Canned
# 1026    Canned
# 1029    Canned
# 1033    Canned
# 1035    Canned
# 1038    Canned
# 1039    Canned
# 1040    Canned
# 1041    Canned
# 1042    Canned
# 1044    Canned
# 1045    Canned
# 1046    Canned
# 1047    Canned
# 1051    Canned
# 1054    Canned
# 1057    Canned
# Name: What type of cranberry saucedo you typically have?, Length: 502, dtype: object

# %%
#Grouping Data
grouped = data.groupby("What type of cranberry saucedo you typically have?")
grouped

# %%
grouped.groups
# Out:
# {'Canned': Int64Index([   4,    6,    8,   11,   12,   15,   18,   19,   26,   27,
#              ...
#              1040, 1041, 1042, 1044, 1045, 1046, 1047, 1051, 1054, 1057],
#             dtype='int64', length=502),
#  'Homemade': Int64Index([   2,    3,    5,    7,   13,   14,   16,   20,   21,   23,
#              ...
#              1016, 1017, 1025, 1027, 1030, 1034, 1048, 1049, 1053, 1056],
#             dtype='int64', length=301),
#  'None': Int64Index([   0,   17,   24,   29,   34,   36,   40,   47,   49,   51,
#              ...
#               980,  981,  997, 1015, 1018, 1031, 1037, 1043, 1050, 1055],
#             dtype='int64', length=146),
#  'Other (please specify)': Int64Index([   1,    9,  154,  216,  221,  233,  249,  265,  301,  336,  380,
#               435,  444,  447,  513,  550,  749,  750,  784,  807,  860,  872,
#               905, 1000, 1007],
#             dtype='int64')}

# %%
grouped.size()

# %%
#grouped.size()
data["What type of cranberry saucedo you typically have?"].value_counts(dropna=False)
# Out:
# Canned                    502
# Homemade                  301
# None                      146
# NaN                        84
# Other (please specify)     25
# Name: What type of cranberry saucedo you typically have?, dtype: int64

# %%
for name, group in grouped:
    print(name)
    print(group.shape)
    print(type(group))
# Out:
# Rural
# (216,)
# <class 'pandas.core.series.Series'>
# Suburban
# (496,)
# <class 'pandas.core.series.Series'>
# Urban
# (236,)
# <class 'pandas.core.series.Series'>

# %%
grouped["income"]
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-38-4e101e915f6a> in <module>()
# ----> 1 grouped["income"]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     240         if self._selection is not None:
#     241             raise Exception('Column(s) {selection} already selected'
# --> 242                             .format(selection=self._selection))
#     243
#     244         if isinstance(key, (list, tuple, ABCSeries, ABCIndexClass,
#
# Exception: Column(s) What is typically the main dish at your Thanksgiving dinner? already selected

# %%
grouped["income"].size()

# %%
print(data["income"])

# %%
#Aggregating Values
#select avg(income) group by sauce
grouped["income"].agg(np.mean)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-37-9b1860e9c79c> in <module>()
#       1 #Aggregating Values
#       2 #select avg(income) group by sauce
# ----> 3 grouped["income"].agg(np.mean)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     240         if self._selection is not None:
#     241             raise Exception('Column(s) {selection} already selected'
# --> 242                             .format(selection=self._selection))
#     243
#     244         if isinstance(key, (list, tuple, ABCSeries, ABCIndexClass,
#
# Exception: Column(s) What is typically the main dish at your Thanksgiving dinner? already selected

# %%
grouped.agg(np.mean)

# %%
grouped.describe()

# %%
#Data Visulalization
# %matplotlib inline

sauce = grouped.agg(np.mean)
sauce
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-36-dd42bdecf74b> in <module>()
#       2 get_ipython().run_line_magic('matplotlib', 'inline')
#       3
# ----> 4 sauce = grouped.agg(np.mean)
#       5 sauce
#       6
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby.py in aggregate(self, func_or_funcs, *args, **kwargs)
#    3127             cyfunc = self._is_cython_func(func_or_funcs)
#    3128             if cyfunc and not args and not kwargs:
# -> 3129                 return getattr(self, cyfunc)()
#    3130
#    3131             if self.grouper.nkeys > 1:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby.py in mean(self, *args, **kwargs)
#    1126         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1127         try:
# -> 1128             return self._cython_agg_general('mean', **kwargs)
#    1129         except GroupByError:
#    1130             raise
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     925
#     926         if len(output) == 0:
# --> 927             raise DataError('No numeric types to aggregate')
#     928
#     929         return self._wrap_aggregated_output(output, names)
#
# DataError: No numeric types to aggregate

# %%
#sauce["income"].plot(kind="bar")
sauce["income"]("canned").plot(kind="pie")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-89d3c8af38eb> in <module>()
#       1 #sauce["income"].plot(kind="bar")
# ----> 2 sauce["income"]("canned").plot(kind="pie")
#
# NameError: name 'sauce' is not defined

# %%
sauce["income"].plot(kind="bar")

# %%
#select avg(all columns) group by sauce,dish
grouped = data.groupby(["What type of cranberry saucedo you typically have?", "What is typically the main dish at your Thanksgiving dinner?"])
grouped.agg(np.mean)

# %%
grouped["income"].agg([np.mean, np.sum, np.std]).head(10)
# Out:
#                                                             mean         sum  \
# What type of cranberry saucedo you typically have?
# Canned                                              83823.403409  36882297.5
# Homemade                                            94878.107287  23434892.5
# None                                                78886.084034   9387444.0
# Other (please specify)                              86629.978261   1992489.5
#
#                                                              std
# What type of cranberry saucedo you typically have?
# Canned                                              55835.478014
# Homemade                                            62251.937645
# None                                                54562.750866
# Other (please specify)                              54175.781001

# %%
#Apply Method
#selet count(*) group by on living,dish
grouped = data.groupby("How would you describe where you live?")["What is typically the main dish at your Thanksgiving dinner?"]
#grouped["income"].value_counts()
grouped.apply(lambda x:x.value_counts())
# Out:
# How would you describe where you live?
# Rural                                   Turkey                    189
#                                         Other (please specify)      9
#                                         Ham/Pork                    7
#                                         Tofurkey                    3
#                                         I don't know                3
#                                         Turducken                   2
#                                         Chicken                     2
#                                         Roast beef                  1
# Suburban                                Turkey                    449
#                                         Ham/Pork                   17
#                                         Other (please specify)     13
#                                         Tofurkey                    9
#                                         Chicken                     3
#                                         Roast beef                  3
#                                         Turducken                   1
#                                         I don't know                1
# Urban                                   Turkey                    198
#                                         Other (please specify)     13
#                                         Tofurkey                    8
#                                         Chicken                     7
#                                         Roast beef                  6
#                                         Ham/Pork                    4
# Name: What is typically the main dish at your Thanksgiving dinner?, dtype: int64

# %%
grouped.describe()
# Out:
#                                        count unique     top freq
# How would you describe where you live?
# Rural                                    216      8  Turkey  189
# Suburban                                 496      8  Turkey  449
# Urban                                    236      6  Turkey  198

# %%
import pandas as pd

df = pd.DataFrame({"Name":["Alice", "Bob", "Mallory", "Mallory", "Bob" , "Mallory"],
                    "City":["Seattle","Seattle","Portland","Seattle","Seattle","Portland"]})
print (df)
# Out:
#        City     Name
# 0   Seattle    Alice
# 1   Seattle      Bob
# 2  Portland  Mallory
# 3   Seattle  Mallory
# 4   Seattle      Bob
# 5  Portland  Mallory

# %%
#to store in another dataframe
df = df['TIME'].groupby(df['Name']).min()
df = df.to_frame()
df = df.reset_index(level=['Name',"TIME"])

#another way to make a new dataframe after goupby
almo_grp_data = pd.DataFrame({'Qty_cnt' :
almo_slt_models_data.groupby( ['orderDate','Item','State Abv']
          )['Qty'].sum()}).reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TIME'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-bab4fb50c49c> in <module>()
#       1 #to store in another dataframe
# ----> 2 df = df['TIME'].groupby(df['Name']).min()
#       3 df = df.to_frame()
#       4 df = df.reset_index(level=['Name',"TIME"])
#       5
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TIME'

# %%
df.to_csv('file1.csv')
