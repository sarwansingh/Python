# %%
import numpy as np
import pandas as pd
df = pd.read_csv("c:\users\admin\pandas_datatype\sales.csv")
df
# Out:
#   File "<ipython-input-2-f230400f46bd>", line 3
#     df = pd.read_csv("c:\users\admin\pandas_datatype\sales.csv")
#                     ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \uXXXX escape
