# %%
#C:\Users\Electronics\AppData\Roaming\nltk_data\corpora\movie_reviews\test
import nltk.classify.util
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import movie_reviews
 
def word_feats(words):
    return dict([(word, True) for word in words])

# %%
negids = movie_reviews.fileids('neg')
posids = movie_reviews.fileids('pos')

# %%
negfeats = [(word_feats(movie_reviews.words(fileids=[f])), 'neg') for f in negids]
posfeats = [(word_feats(movie_reviews.words(fileids=[f])), 'pos') for f in posids]

# %%
#print(posfeats[:1])
negcutoff = int(len(negfeats)*3/4)
poscutoff = int(len(posfeats)*3/4)
print(negcutoff)
# Out:
# 750

# %%
trainfeats = negfeats[:negcutoff] + posfeats[:poscutoff]
testfeats = negfeats[negcutoff:] + posfeats[poscutoff:]
print ('train on %d instances, test on %d instances' % (len(trainfeats), len(testfeats)))
# Out:
# train on 1500 instances, test on 500 instances

# %%
classifier = NaiveBayesClassifier.train(trainfeats)

print ('accuracy:', nltk.classify.util.accuracy(classifier, testfeats))
# Out:
# accuracy: 0.728

# %%
classifier.show_most_informative_features()
# Out:
# Most Informative Features
#              magnificent = True              pos : neg    =     15.0 : 1.0
#              outstanding = True              pos : neg    =     13.6 : 1.0
#                insulting = True              neg : pos    =     13.0 : 1.0
#               vulnerable = True              pos : neg    =     12.3 : 1.0
#                ludicrous = True              neg : pos    =     11.8 : 1.0
#                   avoids = True              pos : neg    =     11.7 : 1.0
#              uninvolving = True              neg : pos    =     11.7 : 1.0
#               astounding = True              pos : neg    =     10.3 : 1.0
#              fascination = True              pos : neg    =     10.3 : 1.0
#                  idiotic = True              neg : pos    =      9.8 : 1.0

# %%
print(len(negids), negids[:5])
# Out:
# 1000 ['neg/cv000_29416.txt', 'neg/cv001_19502.txt', 'neg/cv002_17424.txt', 'neg/cv003_12683.txt', 'neg/cv004_12641.txt']

# %%
print(len(posids), posids[:5])
# Out:
# 1000 ['pos/cv000_29590.txt', 'pos/cv001_18431.txt', 'pos/cv002_15918.txt', 'pos/cv003_11664.txt', 'pos/cv004_11636.txt']

# %%
len(negfeats)
# Out:
# 1000

# %%
negfeats[0]
# Out:
# ({'!': True,
#   '"': True,
#   '&': True,
#   "'": True,
#   '(': True,
#   ')': True,
#   ',': True,
#   '-': True,
#   '.': True,
#   '/': True,
#   '10': True,
#   '2': True,
#   '20': True,
#   '3': True,
#   '4': True,
#   '7': True,
#   '8': True,
#   '9': True,
#   ':': True,
#   '?': True,
#   'a': True,
#   'about': True,
#   'accident': True,
#   'actors': True,
#   'actually': True,
#   'after': True,
#   'again': True,
#   'ago': True,
#   'all': True,
#   'also': True,
#   'although': True,
#   'always': True,
#   'american': True,
#   'an': True,
#   'and': True,
#   'apparently': True,
#   'apparitions': True,
#   'applaud': True,
#   'are': True,
#   'arrow': True,
#   'as': True,
#   'assuming': True,
#   'attempt': True,
#   'audience': True,
#   'away': True,
#   'back': True,
#   'bad': True,
#   'be': True,
#   'beauty': True,
#   'because': True,
#   'been': True,
#   'before': True,
#   'bentley': True,
#   'big': True,
#   'biggest': True,
#   'bit': True,
# ...

# %%
posfeats[0]
# Out:
# ({'"': True,
#   "'": True,
#   '(': True,
#   ')': True,
#   ',': True,
#   '-': True,
#   '.': True,
#   '/': True,
#   '00': True,
#   '102': True,
#   '12': True,
#   '1888': True,
#   '2': True,
#   '30': True,
#   '500': True,
#   '80s': True,
#   ':': True,
#   '?': True,
#   'a': True,
#   'abberline': True,
#   'ably': True,
#   'about': True,
#   'absinthe': True,
#   'accent': True,
#   'acting': True,
#   'acts': True,
#   'actually': True,
#   'adapted': True,
#   'after': True,
#   'alan': True,
#   'albert': True,
#   'all': True,
#   'allen': True,
#   'almost': True,
#   'amounts': True,
#   'an': True,
#   'and': True,
#   'another': True,
#   'anyone': True,
#   'anything': True,
#   'apes': True,
#   'appearance': True,
#   'are': True,
#   'arriving': True,
#   'arthouse': True,
#   'as': True,
#   'at': True,
#   'attempt': True,
#   'back': True,
#   'bad': True,
#   'batman': True,
#   'be': True,
#   'because': True,
#   'been': True,
#   'before': True,
# ...

# %%
print(negcutoff, poscutoff)
# Out:
# 750 750

# %%
movie_reviews.words(fileids='test/testneg.txt')  #name of txt files containing test data
# Out:
# ['that', "'", 's', 'exactly', 'how', 'long', 'the', ...]

# %%
#Testing negative movie reviews
test_data_features=word_feats(movie_reviews.words(fileids='test/testneg.txt'))
print("***")
print (classifier.classify(test_data_features))
# Out:
# ***
# neg

# %%
#Testing positive movie reviews
test_data_features=word_feats(movie_reviews.words(fileids='test/testpos.txt'))
print("***")
print (classifier.classify(test_data_features))
# Out:
# ***
# pos

# %%
#Testing pk movie reviews
test_data_features=word_feats(movie_reviews.words(fileids='test/pk_review.txt'))
print("***")
print (classifier.classify(test_data_features))
# Out:
# ***
# pos

# %%
#Testing raaz movie reviews
test_data_features=word_feats(movie_reviews.words(fileids='test/raazreview.txt'))
print("***")
print (classifier.classify(test_data_features))
# Out:
# ***
# neg

# %%
#Testing negative movie reviews
test_data_features=word_feats(movie_reviews.words(fileids='test/goodnews.txt'))
print("***")
print (classifier.classify(test_data_features))
# Out:
# ***
# pos

# %%
#Testing negative movie reviews
test_data_features=word_feats(movie_reviews.words(fileids='test/st401pos.txt'))
print("***")
print (classifier.classify(test_data_features))
# Out:
# ***
# pos

# %%
#Testing negative movie reviews
test_data_features=word_feats(movie_reviews.words(fileids='test/st401dhadak.txt'))
print("***")
print (classifier.classify(test_data_features))
# Out:
# ***
# pos

# %%
#Testing negative movie reviews
test_data_features=word_feats(movie_reviews.words(fileids='test/raazreview.txt'))
print("***")
print (classifier.classify(test_data_features))
# Out:
# ***
# neg
