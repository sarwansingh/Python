# %%
import math
math.pi
# Out:
# 3.141592653589793

# %%
import numpy as np
np.random.randint(1,10,5)
# Out:
# array([1, 7, 3, 1, 6])

# %% [markdown]
# ## Calling .py file /Module from google Drive

# %%
# using file from google drive 
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#list the *.py files from the gdrive
# !ls /content/gdrive/My\ Drive/*.py
# Out:
# '/content/gdrive/My Drive/myModule.py'

# %%
#display the contents of myModule.py file
# !cat '/content/gdrive/My Drive/myModule.py'
# Out:
# def hiModule():
# 	print('This is Module calling from google drive...')
# 	print('Inside hiModule')
#
# def showMe() :
#     print( 'Champs of N I E L I T Ropar')
#     print('Welcome to AI class')

# %% [markdown]
# We'll need to update our path to import from Drive.

# %%
import sys
sys.path.append('/content/gdrive/My Drive')

# %%
import myModule as m
m.hiModule()
# Out:
# This is Module calling from google drive...
# Inside hiModule

# %%
m.showMe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-e9f03f6e01d7> in <module>()
# ----> 1 m.showMe()
#
# AttributeError: module 'myModule' has no attribute 'showMe'
